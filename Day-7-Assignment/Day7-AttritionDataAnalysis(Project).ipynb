# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing

# %%
df = pd.read_csv('general_data.csv')
df
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# 1                   10          1  Life Sciences              1           2
# 2                   17          4          Other              1           3
# 3                    2          5  Life Sciences              1           4
# 4                   10          1        Medical              1           5
# ...                ...        ...            ...            ...         ...
# 4405                 5          4        Medical              1        4406
# 4406                 2          4        Medical              1        4407
# 4407                25          2  Life Sciences              1        4408
# 4408                18          2        Medical              1        4409
# 4409                28          3        Medical              1        4410
#
#       Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# 0     Female  ...                 1.0      Y                11              8
# 1     Female  ...                 0.0      Y                23              8
# 2       Male  ...                 1.0      Y                15              8
# 3       Male  ...                 3.0      Y                11              8
# 4       Male  ...                 4.0      Y                12              8
# ...      ...  ...                 ...    ...               ...            ...
# 4405  Female  ...                 3.0      Y                17              8
# 4406    Male  ...                 2.0      Y                15              8
# 4407    Male  ...                 0.0      Y                20              8
# 4408    Male  ...                 0.0      Y                14              8
# 4409    Male  ...                 0.0      Y                12              8
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0               1.0                      6
# 1                    1               6.0                      3
# 2                    3               5.0                      2
# 3                    3              13.0                      5
# 4                    2               9.0                      2
# ...                ...               ...                    ...
# 4405                 1              10.0                      5
# 4406                 0              10.0                      2
# 4407                 0               5.0                      4
# 4408                 1              10.0                      2
# 4409                 0               NaN                      6
#
#       YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  1                        0                     0
# 1                  5                        1                     4
# 2                  5                        0                     3
# 3                  8                        7                     5
# 4                  6                        0                     4
# ...              ...                      ...                   ...
# 4405               3                        0                     2
# 4406               3                        0                     2
# 4407               4                        1                     2
# 4408               9                        7                     8
# 4409              21                        3                     9
#
# [4410 rows x 24 columns]

# %%
#Check Null Values 
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeID                  0
# Gender                      0
# JobLevel                    0
# JobRole                     0
# MaritalStatus               0
# MonthlyIncome               0
# NumCompaniesWorked         19
# Over18                      0
# PercentSalaryHike           0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           9
# TrainingTimesLastYear       0
# YearsAtCompany              0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# # Finding out the mean and filling the null values

# %%
#check mean to fill null values
df[['NumCompaniesWorked', 'TotalWorkingYears']].mean()
# Out:
# NumCompaniesWorked     2.694830
# TotalWorkingYears     11.279936
# dtype: float64

# %%
# filling up null values with their mean
df['NumCompaniesWorked'] = df['NumCompaniesWorked'].fillna(2.69) 
df['TotalWorkingYears'] = df['TotalWorkingYears'].fillna(11.28)
# checking if it is filled
df.isnull().sum()
# Out:
# Age                        0
# Attrition                  0
# BusinessTravel             0
# Department                 0
# DistanceFromHome           0
# Education                  0
# EducationField             0
# EmployeeCount              0
# EmployeeID                 0
# Gender                     0
# JobLevel                   0
# JobRole                    0
# MaritalStatus              0
# MonthlyIncome              0
# NumCompaniesWorked         0
# Over18                     0
# PercentSalaryHike          0
# StandardHours              0
# StockOptionLevel           0
# TotalWorkingYears          0
# TrainingTimesLastYear      0
# YearsAtCompany             0
# YearsSinceLastPromotion    0
# YearsWithCurrManager       0
# dtype: int64

# %%
# Do a Label Encoding to Change the Non Numerical Values
le = preprocessing.LabelEncoder()
df['Attrition'] = le.fit_transform(df['Attrition'])
df['BusinessTravel'] = le.fit_transform(df['BusinessTravel'])
df['EducationField'] = le.fit_transform(df['EducationField'])
df['Gender'] = le.fit_transform(df['Gender'])
df['Department'] = le.fit_transform(df['Department'])
df['MaritalStatus'] = le.fit_transform(df['MaritalStatus'])
df['JobRole'] = le.fit_transform(df['JobRole'])

df
# Out:
#       Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0      51          0               2           2                 6          2
# 1      31          1               1           1                10          1
# 2      32          0               1           1                17          4
# 3      38          0               0           1                 2          5
# 4      32          0               2           1                10          1
# ...   ...        ...             ...         ...               ...        ...
# 4405   42          0               2           1                 5          4
# 4406   29          0               2           1                 2          4
# 4407   25          0               2           1                25          2
# 4408   42          0               2           2                18          2
# 4409   40          0               2           1                28          3
#
#       EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0                  1              1           1       0  ...
# 1                  1              1           2       0  ...
# 2                  4              1           3       1  ...
# 3                  1              1           4       1  ...
# 4                  3              1           5       1  ...
# ...              ...            ...         ...     ...  ...
# 4405               3              1        4406       0  ...
# 4406               3              1        4407       1  ...
# 4407               1              1        4408       1  ...
# 4408               3              1        4409       1  ...
# 4409               3              1        4410       1  ...
#
#       NumCompaniesWorked  Over18  PercentSalaryHike  StandardHours  \
# 0                    1.0       Y                 11              8
# 1                    0.0       Y                 23              8
# 2                    1.0       Y                 15              8
# 3                    3.0       Y                 11              8
# 4                    4.0       Y                 12              8
# ...                  ...     ...                ...            ...
# 4405                 3.0       Y                 17              8
# 4406                 2.0       Y                 15              8
# 4407                 0.0       Y                 20              8
# 4408                 0.0       Y                 14              8
# 4409                 0.0       Y                 12              8
#
#       StockOptionLevel TotalWorkingYears  TrainingTimesLastYear  \
# 0                    0              1.00                      6
# 1                    1              6.00                      3
# 2                    3              5.00                      2
# 3                    3             13.00                      5
# 4                    2              9.00                      2
# ...                ...               ...                    ...
# 4405                 1             10.00                      5
# 4406                 0             10.00                      2
# 4407                 0              5.00                      4
# 4408                 1             10.00                      2
# 4409                 0             11.28                      6
#
#       YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# 0                  1                        0                     0
# 1                  5                        1                     4
# 2                  5                        0                     3
# 3                  8                        7                     5
# 4                  6                        0                     4
# ...              ...                      ...                   ...
# 4405               3                        0                     2
# 4406               3                        0                     2
# 4407               4                        1                     2
# 4408               9                        7                     8
# 4409              21                        3                     9
#
# [4410 rows x 24 columns]

# %%
#making a new dataframe with the columns to work on
df1 = df[['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
       'Education', 'EducationField','Gender', 'MaritalStatus',
       'JobLevel', 'JobRole', 'MonthlyIncome',
       'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager']]
#making variables to store Attrition values
df_y = df1[df1['Attrition']==1]
df_n = df1[df1['Attrition']==0]
cols = list(df1.columns)

# %% [markdown]
# # Obtaining Basic Stats of the Data

# %%
df1[['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
       'Education', 'EducationField','Gender', 'MaritalStatus',
       'JobLevel', 'JobRole', 'MonthlyIncome',
       'NumCompaniesWorked']].describe()
# Out:
#                Age    Attrition  BusinessTravel   Department  \
# count  4410.000000  4410.000000     4410.000000  4410.000000
# mean     36.923810     0.161224        1.607483     1.260544
# std       9.133301     0.367780        0.665304     0.527673
# min      18.000000     0.000000        0.000000     0.000000
# 25%      30.000000     0.000000        1.000000     1.000000
# 50%      36.000000     0.000000        2.000000     1.000000
# 75%      43.000000     0.000000        2.000000     2.000000
# max      60.000000     1.000000        2.000000     2.000000
#
#        DistanceFromHome    Education  EducationField       Gender  \
# count       4410.000000  4410.000000     4410.000000  4410.000000
# mean           9.192517     2.912925        2.247619     0.600000
# std            8.105026     1.023933        1.331067     0.489954
# min            1.000000     1.000000        0.000000     0.000000
# 25%            2.000000     2.000000        1.000000     0.000000
# 50%            7.000000     3.000000        2.000000     1.000000
# 75%           14.000000     4.000000        3.000000     1.000000
# max           29.000000     5.000000        5.000000     1.000000
#
#        MaritalStatus     JobLevel      JobRole  MonthlyIncome  \
# count    4410.000000  4410.000000  4410.000000    4410.000000
# mean        1.097279     2.063946     4.458503   65029.312925
# std         0.729955     1.106689     2.461263   47068.888559
# min         0.000000     1.000000     0.000000   10090.000000
# 25%         1.000000     1.000000     2.000000   29110.000000
# 50%         1.000000     2.000000     5.000000   49190.000000
# 75%         2.000000     3.000000     7.000000   83800.000000
# max         2.000000     5.000000     8.000000  199990.000000
#
#        NumCompaniesWorked
# count         4410.000000
# mean             2.694810
# std              2.493497
# min              0.000000
# 25%              1.000000
# 50%              2.000000
# 75%              4.000000
# max              9.000000

# %%
df1[['PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
# Out:
#        PercentSalaryHike  TotalWorkingYears  TrainingTimesLastYear  \
# count        4410.000000        4410.000000            4410.000000
# mean           15.209524          11.279937               2.799320
# std             3.659108           7.774275               1.288978
# min            11.000000           0.000000               0.000000
# 25%            12.000000           6.000000               2.000000
# 50%            14.000000          10.000000               3.000000
# 75%            18.000000          15.000000               3.000000
# max            25.000000          40.000000               6.000000
#
#        YearsAtCompany  YearsSinceLastPromotion  YearsWithCurrManager
# count     4410.000000              4410.000000           4410.000000
# mean         7.008163                 2.187755              4.123129
# std          6.125135                 3.221699              3.567327
# min          0.000000                 0.000000              0.000000
# 25%          3.000000                 0.000000              2.000000
# 50%          5.000000                 1.000000              3.000000
# 75%          9.000000                 3.000000              7.000000
# max         40.000000                15.000000             17.000000

# %%
# Finding out the mode
df1.mode()
# Out:
#    Age  Attrition  BusinessTravel  Department  DistanceFromHome  Education  \
# 0   35          0               2           1                 2          3
#
#    EducationField  Gender  MaritalStatus  JobLevel  JobRole  MonthlyIncome  \
# 0               1       1              1         1        7          23420
#
#    NumCompaniesWorked  PercentSalaryHike  TotalWorkingYears  \
# 0                 1.0                 11               10.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      2               5                        0
#
#    YearsWithCurrManager
# 0                     2

# %%
# Finding out the median
df_med = pd.DataFrame(df1.median(), columns = ['Median'])
df_med
# Out:
#                           Median
# Age                         36.0
# Attrition                    0.0
# BusinessTravel               2.0
# Department                   1.0
# DistanceFromHome             7.0
# Education                    3.0
# EducationField               2.0
# Gender                       1.0
# MaritalStatus                1.0
# JobLevel                     2.0
# JobRole                      5.0
# MonthlyIncome            49190.0
# NumCompaniesWorked           2.0
# PercentSalaryHike           14.0
# TotalWorkingYears           10.0
# TrainingTimesLastYear        3.0
# YearsAtCompany               5.0
# YearsSinceLastPromotion      1.0
# YearsWithCurrManager         3.0

# %%
# Finding out the variance
df_var = pd.DataFrame(df1.var(), columns = ['Variance'])
df_var
# Out:
#                              Variance
# Age                      8.341719e+01
# Attrition                1.352618e-01
# BusinessTravel           4.426294e-01
# Department               2.784384e-01
# DistanceFromHome         6.569144e+01
# Education                1.048438e+00
# EducationField           1.771740e+00
# Gender                   2.400544e-01
# MaritalStatus            5.328345e-01
# JobLevel                 1.224760e+00
# JobRole                  6.057815e+00
# MonthlyIncome            2.215480e+09
# NumCompaniesWorked       6.217526e+00
# PercentSalaryHike        1.338907e+01
# TotalWorkingYears        6.043936e+01
# TrainingTimesLastYear    1.661465e+00
# YearsAtCompany           3.751728e+01
# YearsSinceLastPromotion  1.037935e+01
# YearsWithCurrManager     1.272582e+01

# %%
# Finding out the variance
df_var = pd.DataFrame(df1.var(), columns = ['Variance'])
df_var
# Out:
#                              Variance
# Age                      8.341719e+01
# Attrition                1.352618e-01
# BusinessTravel           4.426294e-01
# Department               2.784384e-01
# DistanceFromHome         6.569144e+01
# Education                1.048438e+00
# EducationField           1.771740e+00
# Gender                   2.400544e-01
# MaritalStatus            5.328345e-01
# JobLevel                 1.224760e+00
# JobRole                  6.057815e+00
# MonthlyIncome            2.215480e+09
# NumCompaniesWorked       6.217526e+00
# PercentSalaryHike        1.338907e+01
# TotalWorkingYears        6.043936e+01
# TrainingTimesLastYear    1.661465e+00
# YearsAtCompany           3.751728e+01
# YearsSinceLastPromotion  1.037935e+01
# YearsWithCurrManager     1.272582e+01

# %% [raw]
# Age, Department, EducationField, Education and TrainingTimesLastYear are having skewness between -0.5 and 0.5 hence, they are approximately symmetrical

# %% [markdown]
# # Visualisation the Stats

# %%
sns.distplot(df1['Age'])
plt.show()

# %%
plt.hist(df1['Education'])
plt.show()

# %%
plt.hist(df1['TrainingTimesLastYear'])
plt.show()

# %%
# Finding out the Kurtosis
df_kurt = pd.DataFrame(df1.kurt(), columns = ['Kurtosis'])
df_kurt
# Out:
#                          Kurtosis
# Age                     -0.405951
# Attrition                1.397690
# BusinessTravel           0.698371
# Department              -0.393269
# DistanceFromHome        -0.227045
# Education               -0.560569
# EducationField          -0.689242
# Gender                  -1.834052
# MaritalStatus           -1.115231
# JobLevel                 0.395525
# JobRole                 -1.192752
# MonthlyIncome            1.000232
# NumCompaniesWorked       0.020337
# PercentSalaryHike       -0.302638
# TotalWorkingYears        0.920937
# TrainingTimesLastYear    0.491149
# YearsAtCompany           3.923864
# YearsSinceLastPromotion  3.601761
# YearsWithCurrManager     0.167949

# %% [markdown]
# # Checking for Outliers

# %%
plt.boxplot(df['Age'])
plt.show()

# %% [raw]
# Age is normally distributed with no outliers

# %%
plt.boxplot(df['MonthlyIncome'])
plt.show()

# %% [raw]
# Outliers in Monthly Income

# %% [markdown]
# # Performing Non Parametric Tests

# %% [markdown]
# # Mann Whitney Test

# %%
# Preprocessing making a dataframe of continuous columns
cols_cont = df[['Age', 'DistanceFromHome', 'MonthlyIncome',
       'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears', 'TrainingTimesLastYear',
       'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager']]

# %%
from scipy.stats import mannwhitneyu

# %%
# making function to run mannwhitney test for a column against attrition
def mwtest(column):
    
    stats, p = mannwhitneyu(df_y[column], df_n[column])
    print(f"\tp value is {round(p, 3)}\n")
    
# making a function to print all continuous columns vs attrition along with hypothesis and decision 
def mwtest_all(colname):
    print(f"{colname} vs Attrition: \n")
    print(f"\tH0: There are no significant differences in the {colname} between attrition (Y) and attirition (N)")
    print(f"\tH1: There are significant differences in the {colname} between attrition (Y) and attirition (N)")
    print("\n")
    print("\tPerforming MannWhitneyU Test:")
    stats, p = mannwhitneyu(df_y[colname], df_n[colname])
    print(f"\tObtained p value is {round(p, 3)}\n")
    if p < 0.05:
        print(f"\tAs the P value of {round(p, 3)} is < 0.05, the H0 is rejected and H1 is accepted.")
        print(f"\tTherefore, there are significant differences in the {colname} between attrition (Y) and attirition (N)")
    else:
        print(f"\tAs the P value of {round(p, 3)} is > 0.05, the H0 is accepted and H1 is rejected.")
        print(f"\tTherefore, there are no significant differences in the {colname} between attrition (Y) and attirition (N)")
    print("\n ----------- \n")

# %%
# running the test
cols = list(cols_cont.columns)
for col in cols:
    mwtest_all(col)
# Out:
# Age vs Attrition:
#
# 	H0: There are no significant differences in the Age between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the Age between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.0
#
# 	As the P value of 0.0 is < 0.05, the H0 is rejected and H1 is accepted.
# 	Therefore, there are significant differences in the Age between attrition (Y) and attirition (N)
#
#  -----------
#
# DistanceFromHome vs Attrition:
#
# 	H0: There are no significant differences in the DistanceFromHome between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the DistanceFromHome between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.463
#
# 	As the P value of 0.463 is > 0.05, the H0 is accepted and H1 is rejected.
# 	Therefore, there are no significant differences in the DistanceFromHome between attrition (Y) and attirition (N)
#
#  -----------
#
# MonthlyIncome vs Attrition:
#
# 	H0: There are no significant differences in the MonthlyIncome between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the MonthlyIncome between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.054
#
# 	As the P value of 0.054 is > 0.05, the H0 is accepted and H1 is rejected.
# 	Therefore, there are no significant differences in the MonthlyIncome between attrition (Y) and attirition (N)
#
#  -----------
#
# NumCompaniesWorked vs Attrition:
#
# 	H0: There are no significant differences in the NumCompaniesWorked between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the NumCompaniesWorked between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.028
#
# 	As the P value of 0.028 is < 0.05, the H0 is rejected and H1 is accepted.
# 	Therefore, there are significant differences in the NumCompaniesWorked between attrition (Y) and attirition (N)
#
#  -----------
#
# PercentSalaryHike vs Attrition:
#
# 	H0: There are no significant differences in the PercentSalaryHike between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the PercentSalaryHike between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.019
#
# 	As the P value of 0.019 is < 0.05, the H0 is rejected and H1 is accepted.
# 	Therefore, there are significant differences in the PercentSalaryHike between attrition (Y) and attirition (N)
#
#  -----------
#
# TotalWorkingYears vs Attrition:
#
# 	H0: There are no significant differences in the TotalWorkingYears between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the TotalWorkingYears between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.0
#
# 	As the P value of 0.0 is < 0.05, the H0 is rejected and H1 is accepted.
# 	Therefore, there are significant differences in the TotalWorkingYears between attrition (Y) and attirition (N)
#
#  -----------
#
# TrainingTimesLastYear vs Attrition:
#
# 	H0: There are no significant differences in the TrainingTimesLastYear between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the TrainingTimesLastYear between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.005
#
# 	As the P value of 0.005 is < 0.05, the H0 is rejected and H1 is accepted.
# 	Therefore, there are significant differences in the TrainingTimesLastYear between attrition (Y) and attirition (N)
#
#  -----------
#
# YearsAtCompany vs Attrition:
#
# 	H0: There are no significant differences in the YearsAtCompany between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the YearsAtCompany between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.0
#
# 	As the P value of 0.0 is < 0.05, the H0 is rejected and H1 is accepted.
# 	Therefore, there are significant differences in the YearsAtCompany between attrition (Y) and attirition (N)
#
#  -----------
#
# YearsSinceLastPromotion vs Attrition:
#
# 	H0: There are no significant differences in the YearsSinceLastPromotion between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the YearsSinceLastPromotion between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.0
#
# 	As the P value of 0.0 is < 0.05, the H0 is rejected and H1 is accepted.
# 	Therefore, there are significant differences in the YearsSinceLastPromotion between attrition (Y) and attirition (N)
#
#  -----------
#
# YearsWithCurrManager vs Attrition:
#
# 	H0: There are no significant differences in the YearsWithCurrManager between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the YearsWithCurrManager between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.0
#
# 	As the P value of 0.0 is < 0.05, the H0 is rejected and H1 is accepted.
# 	Therefore, there are significant differences in the YearsWithCurrManager between attrition (Y) and attirition (N)
#
#  -----------

# %%
from scipy.stats import chi2_contingency
df_chi = pd.read_csv('general_data.csv')

# %%
# making a function to run ChiSquare Test and print out the hypothesis and result
def chitest(column):
    print(f"ChiSquare Test to check for dependency between Attrition and {column}-\n\n")
    print(f"\tH0: There is no dependency between Attrition and {column}")
    print(f"\tH1: There is dependency between Attrition and {column}")
    
    chitable = pd.crosstab(df_chi[column], df_chi['Attrition'])
    print("\nChitbale:\n\n",chitable)
    stats, p, dof, expected = chi2_contingency(chitable)
    print(f"\n\tObtained p value is {round(p, 3)}")
    
    if p > 0.05:
        print(f"\n\tSince here p value {round(p,3)} is > 0.05 we accept the null hypothesis")
        print(f"\n\tTherefore, there is no dependency between Attrition and {column}\n\n----------\n")
    else:
        print(f"\n\tSince here p value {round(p,3)} is < 0.05 we reject the null hypothesis")
        print(f"\n\tTherefore, there is dependency between Attrition and {column}\n\n----------\n")

# %%
df_cat = df_chi[['Education', 'BusinessTravel', 'Gender', 'Department', 'EducationField', 'JobLevel', 'JobRole', 'MaritalStatus', 'StockOptionLevel']].columns
for col in df_cat:
    chitest(col)
# Out:
# ChiSquare Test to check for dependency between Attrition and Education-
#
#
# 	H0: There is no dependency between Attrition and Education
# 	H1: There is dependency between Attrition and Education
#
# Chitbale:
#
#  Attrition    No  Yes
# Education
# 1           432   78
# 2           687  159
# 3          1449  267
# 4          1008  186
# 5           123   21
#
# 	Obtained p value is 0.228
#
# 	Since here p value 0.228 is > 0.05 we accept the null hypothesis
#
# 	Therefore, there is no dependency between Attrition and Education
#
# ----------
#
# ChiSquare Test to check for dependency between Attrition and BusinessTravel-
#
#
# 	H0: There is no dependency between Attrition and BusinessTravel
# 	H1: There is dependency between Attrition and BusinessTravel
#
# Chitbale:
#
#  Attrition            No  Yes
# BusinessTravel
# Non-Travel          414   36
# Travel_Frequently   624  207
# Travel_Rarely      2661  468
#
# 	Obtained p value is 0.0
#
# 	Since here p value 0.0 is < 0.05 we reject the null hypothesis
#
# 	Therefore, there is dependency between Attrition and BusinessTravel
#
# ----------
#
# ChiSquare Test to check for dependency between Attrition and Gender-
#
#
# 	H0: There is no dependency between Attrition and Gender
# 	H1: There is dependency between Attrition and Gender
#
# Chitbale:
#
#  Attrition    No  Yes
# Gender
# Female     1494  270
# Male       2205  441
#
# 	Obtained p value is 0.245
#
# 	Since here p value 0.245 is > 0.05 we accept the null hypothesis
#
# 	Therefore, there is no dependency between Attrition and Gender
#
# ----------
#
# ChiSquare Test to check for dependency between Attrition and Department-
#
#
# 	H0: There is no dependency between Attrition and Department
# 	H1: There is dependency between Attrition and Department
#
# Chitbale:
#
#  Attrition                 No  Yes
# Department
# Human Resources          132   57
# Research & Development  2430  453
# Sales                   1137  201
#
# 	Obtained p value is 0.0
#
# 	Since here p value 0.0 is < 0.05 we reject the null hypothesis
#
# 	Therefore, there is dependency between Attrition and Department
#
# ----------
#
# ChiSquare Test to check for dependency between Attrition and EducationField-
#
#
# 	H0: There is no dependency between Attrition and EducationField
# 	H1: There is dependency between Attrition and EducationField
#
# Chitbale:
#
#  Attrition           No  Yes
# EducationField
# Human Resources     48   33
# Life Sciences     1515  303
# Marketing          402   75
# Medical           1167  225
# Other              216   30
# Technical Degree   351   45
#
# 	Obtained p value is 0.0
#
# 	Since here p value 0.0 is < 0.05 we reject the null hypothesis
#
# 	Therefore, there is dependency between Attrition and EducationField
#
# ----------
#
# ChiSquare Test to check for dependency between Attrition and JobLevel-
#
#
# 	H0: There is no dependency between Attrition and JobLevel
# 	H1: There is dependency between Attrition and JobLevel
#
# Chitbale:
#
#  Attrition    No  Yes
# JobLevel
# 1          1377  252
# 2          1317  285
# 3           558   96
# 4           267   51
# 5           180   27
#
# 	Obtained p value is 0.18
#
# 	Since here p value 0.18 is > 0.05 we accept the null hypothesis
#
# 	Therefore, there is no dependency between Attrition and JobLevel
#
# ----------
#
# ChiSquare Test to check for dependency between Attrition and JobRole-
#
#
# 	H0: There is no dependency between Attrition and JobRole
# 	H1: There is dependency between Attrition and JobRole
#
# Chitbale:
#
#  Attrition                   No  Yes
# JobRole
# Healthcare Representative  336   57
# Human Resources            135   21
# Laboratory Technician      651  126
# Manager                    264   42
# Manufacturing Director     387   48
# Research Director          183   57
# Research Scientist         717  159
# Sales Executive            813  165
# Sales Representative       213   36
#
# 	Obtained p value is 0.001
#
# 	Since here p value 0.001 is < 0.05 we reject the null hypothesis
#
# 	Therefore, there is dependency between Attrition and JobRole
#
# ----------
#
# ChiSquare Test to check for dependency between Attrition and MaritalStatus-
#
#
# 	H0: There is no dependency between Attrition and MaritalStatus
# 	H1: There is dependency between Attrition and MaritalStatus
#
# Chitbale:
#
#  Attrition        No  Yes
# MaritalStatus
# Divorced        882   99
# Married        1767  252
# Single         1050  360
#
# 	Obtained p value is 0.0
#
# 	Since here p value 0.0 is < 0.05 we reject the null hypothesis
#
# 	Therefore, there is dependency between Attrition and MaritalStatus
#
# ----------
#
# ChiSquare Test to check for dependency between Attrition and StockOptionLevel-
#
#
# 	H0: There is no dependency between Attrition and StockOptionLevel
# 	H1: There is dependency between Attrition and StockOptionLevel
#
# Chitbale:
#
#  Attrition           No  Yes
# StockOptionLevel
# 0                 1575  318
# 1                 1518  270
# 2                  390   84
# 3                  216   39
#
# 	Obtained p value is 0.385
#
# 	Since here p value 0.385 is > 0.05 we accept the null hypothesis
#
# 	Therefore, there is no dependency between Attrition and StockOptionLevel
#
# ----------

# %% [markdown]
# # Performing Parametric Test

# %% [markdown]
# # T- Test

# %%
from scipy.stats import ttest_ind
# making a function to perform separate t test and print hypothesis statements and decision
def test_t(colname):
    print(f"{colname} vs Attrition: \n")
    print(f"\tH0: There are no significant differences in the {colname} between attrition (Y) and attirition (N)")
    print(f"\tH1: There are significant differences in the {colname} between attrition (Y) and attirition (N)")
    print("\n")
    print("\tPerforming MannWhitneyU Test:")
    stats, p = ttest_ind(df_y[colname], df_n[colname])
    print(f"\tObtained p value is {round(p, 3)}\n")
    if p < 0.05:
        print(f"\tAs the P value of {round(p, 3)} is < 0.05, the H0 is rejected and H1 is accepted.")
        print(f"\tTherefore, there are significant differences in the {colname} between attrition (Y) and attirition (N)")
    else:
        print(f"\tAs the P value of {round(p, 3)} is > 0.05, the H0 is accepted and H1 is rejected.")
        print(f"\tTherefore, there no are significant differences in the {colname} between attrition (Y) and attirition (N)")
    print("\n ----------- \n")

# %%
test_t('Age')
# Out:
# Age vs Attrition:
#
# 	H0: There are no significant differences in the Age between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the Age between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.0
#
# 	As the P value of 0.0 is < 0.05, the H0 is rejected and H1 is accepted.
# 	Therefore, there are significant differences in the Age between attrition (Y) and attirition (N)
#
#  -----------

# %%
test_t('TrainingTimesLastYear')
# Out:
# TrainingTimesLastYear vs Attrition:
#
# 	H0: There are no significant differences in the TrainingTimesLastYear between attrition (Y) and attirition (N)
# 	H1: There are significant differences in the TrainingTimesLastYear between attrition (Y) and attirition (N)
#
#
# 	Performing MannWhitneyU Test:
# 	Obtained p value is 0.001
#
# 	As the P value of 0.001 is < 0.05, the H0 is rejected and H1 is accepted.
# 	Therefore, there are significant differences in the TrainingTimesLastYear between attrition (Y) and attirition (N)
#
#  -----------

# %% [markdown]
# # Correlation Analysis

# %%
from scipy.stats import pearsonr

# %%
def corr_an (column):
    print(f"Correlation Analysis of Attrition vs {column}:\n")
    print(f"\tH0: There is no significant relation between Attrition and {column}")
    print(f"\tH1: There is significant relation between Attrition and {column}\n")
    corr_, p = pearsonr(df['Attrition'], df[column])
    corr_ = round(corr_, 3)
    p = round(corr_, 3)
    
    
    if p > 0.05:
        print(f"\n\tHere, the P value of {p} is > 0.05 so we are accepting H0 \n\tHence there is no significant correlation between Attrition and {column}")
    else:
        print(f"\n\tHere, the P value of {p} is < 0.05 so we are rejecting H0 \n\tHence there is significant correlation between Attrition and {column}") 
        if corr_ >= 0 and corr_ < 0.50:
            print(f"\tAs R = {corr_}, there is low positive correlation between Attrition and {column}")
        elif corr_ >= 0.50 and corr_ < 0.70:
            print(f"\tAs R = {corr_}, there is moderate positive correlation between Attrition and {column}")
        elif corr_ >= 0.70 and corr_ < 0.90:
            print(f"\tAs R = {corr_}, there is high positive correlation between Attrition and {column}")
        elif corr_ >= 0.90 and corr_ <= 0.1:
            print(f"\tAs R = {corr_}, there is very high positive correlation between Attrition and {column}")
        elif corr_ <= 0 and corr_ > -0.50:
            print(f"\tAs R = {corr_}, there is low negative correlation between Attrition and {column}")
        elif corr_ <= -0.50 and corr_ > -0.70:
            print(f"\tAs R = {corr_}, there is moderate negative correlation between Attrition and {column}")
        elif corr_ <= -0.70 and corr_ > 0.90:
            print(f"\tAs R = {corr_}, there is high negative correlation between Attrition and {column}")
        else:
            print(f"\tAs R = {corr_}, there is very high negative correlation between Attrition and {column}")
            
    print("\n----------\n")

# %%
df_cor = df.drop(columns = ['Attrition', 'EmployeeID', 'EmployeeCount', 'Over18', 'StandardHours'])
df_cor.columns
for col in df_cor.columns:
    corr_an(col)
# Out:
# Correlation Analysis of Attrition vs Age:
#
# 	H0: There is no significant relation between Attrition and Age
# 	H1: There is significant relation between Attrition and Age
#
#
# 	Here, the P value of -0.159 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and Age
# 	As R = -0.159, there is low negative correlation between Attrition and Age
#
# ----------
#
# Correlation Analysis of Attrition vs BusinessTravel:
#
# 	H0: There is no significant relation between Attrition and BusinessTravel
# 	H1: There is significant relation between Attrition and BusinessTravel
#
#
# 	Here, the P value of 0.0 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and BusinessTravel
# 	As R = 0.0, there is low positive correlation between Attrition and BusinessTravel
#
# ----------
#
# Correlation Analysis of Attrition vs Department:
#
# 	H0: There is no significant relation between Attrition and Department
# 	H1: There is significant relation between Attrition and Department
#
#
# 	Here, the P value of -0.048 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and Department
# 	As R = -0.048, there is low negative correlation between Attrition and Department
#
# ----------
#
# Correlation Analysis of Attrition vs DistanceFromHome:
#
# 	H0: There is no significant relation between Attrition and DistanceFromHome
# 	H1: There is significant relation between Attrition and DistanceFromHome
#
#
# 	Here, the P value of -0.01 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and DistanceFromHome
# 	As R = -0.01, there is low negative correlation between Attrition and DistanceFromHome
#
# ----------
#
# Correlation Analysis of Attrition vs Education:
#
# 	H0: There is no significant relation between Attrition and Education
# 	H1: There is significant relation between Attrition and Education
#
#
# 	Here, the P value of -0.015 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and Education
# 	As R = -0.015, there is low negative correlation between Attrition and Education
#
# ----------
#
# Correlation Analysis of Attrition vs EducationField:
#
# 	H0: There is no significant relation between Attrition and EducationField
# 	H1: There is significant relation between Attrition and EducationField
#
#
# 	Here, the P value of -0.058 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and EducationField
# 	As R = -0.058, there is low negative correlation between Attrition and EducationField
#
# ----------
#
# Correlation Analysis of Attrition vs Gender:
#
# 	H0: There is no significant relation between Attrition and Gender
# 	H1: There is significant relation between Attrition and Gender
#
#
# 	Here, the P value of 0.018 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and Gender
# 	As R = 0.018, there is low positive correlation between Attrition and Gender
#
# ----------
#
# Correlation Analysis of Attrition vs JobLevel:
#
# 	H0: There is no significant relation between Attrition and JobLevel
# 	H1: There is significant relation between Attrition and JobLevel
#
#
# 	Here, the P value of -0.01 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and JobLevel
# 	As R = -0.01, there is low negative correlation between Attrition and JobLevel
#
# ----------
#
# Correlation Analysis of Attrition vs JobRole:
#
# 	H0: There is no significant relation between Attrition and JobRole
# 	H1: There is significant relation between Attrition and JobRole
#
#
# 	Here, the P value of 0.026 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and JobRole
# 	As R = 0.026, there is low positive correlation between Attrition and JobRole
#
# ----------
#
# Correlation Analysis of Attrition vs MaritalStatus:
#
# 	H0: There is no significant relation between Attrition and MaritalStatus
# 	H1: There is significant relation between Attrition and MaritalStatus
#
#
# 	Here, the P value of 0.162 is > 0.05 so we are accepting H0
# 	Hence there is no significant correlation between Attrition and MaritalStatus
#
# ----------
#
# Correlation Analysis of Attrition vs MonthlyIncome:
#
# 	H0: There is no significant relation between Attrition and MonthlyIncome
# 	H1: There is significant relation between Attrition and MonthlyIncome
#
#
# 	Here, the P value of -0.031 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and MonthlyIncome
# 	As R = -0.031, there is low negative correlation between Attrition and MonthlyIncome
#
# ----------
#
# Correlation Analysis of Attrition vs NumCompaniesWorked:
#
# 	H0: There is no significant relation between Attrition and NumCompaniesWorked
# 	H1: There is significant relation between Attrition and NumCompaniesWorked
#
#
# 	Here, the P value of 0.042 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and NumCompaniesWorked
# 	As R = 0.042, there is low positive correlation between Attrition and NumCompaniesWorked
#
# ----------
#
# Correlation Analysis of Attrition vs PercentSalaryHike:
#
# 	H0: There is no significant relation between Attrition and PercentSalaryHike
# 	H1: There is significant relation between Attrition and PercentSalaryHike
#
#
# 	Here, the P value of 0.033 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and PercentSalaryHike
# 	As R = 0.033, there is low positive correlation between Attrition and PercentSalaryHike
#
# ----------
#
# Correlation Analysis of Attrition vs StockOptionLevel:
#
# 	H0: There is no significant relation between Attrition and StockOptionLevel
# 	H1: There is significant relation between Attrition and StockOptionLevel
#
#
# 	Here, the P value of -0.007 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and StockOptionLevel
# 	As R = -0.007, there is low negative correlation between Attrition and StockOptionLevel
#
# ----------
#
# Correlation Analysis of Attrition vs TotalWorkingYears:
#
# 	H0: There is no significant relation between Attrition and TotalWorkingYears
# 	H1: There is significant relation between Attrition and TotalWorkingYears
#
#
# 	Here, the P value of -0.17 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and TotalWorkingYears
# 	As R = -0.17, there is low negative correlation between Attrition and TotalWorkingYears
#
# ----------
#
# Correlation Analysis of Attrition vs TrainingTimesLastYear:
#
# 	H0: There is no significant relation between Attrition and TrainingTimesLastYear
# 	H1: There is significant relation between Attrition and TrainingTimesLastYear
#
#
# 	Here, the P value of -0.049 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and TrainingTimesLastYear
# 	As R = -0.049, there is low negative correlation between Attrition and TrainingTimesLastYear
#
# ----------
#
# Correlation Analysis of Attrition vs YearsAtCompany:
#
# 	H0: There is no significant relation between Attrition and YearsAtCompany
# 	H1: There is significant relation between Attrition and YearsAtCompany
#
#
# 	Here, the P value of -0.134 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and YearsAtCompany
# 	As R = -0.134, there is low negative correlation between Attrition and YearsAtCompany
#
# ----------
#
# Correlation Analysis of Attrition vs YearsSinceLastPromotion:
#
# 	H0: There is no significant relation between Attrition and YearsSinceLastPromotion
# 	H1: There is significant relation between Attrition and YearsSinceLastPromotion
#
#
# 	Here, the P value of -0.033 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and YearsSinceLastPromotion
# 	As R = -0.033, there is low negative correlation between Attrition and YearsSinceLastPromotion
#
# ----------
#
# Correlation Analysis of Attrition vs YearsWithCurrManager:
#
# 	H0: There is no significant relation between Attrition and YearsWithCurrManager
# 	H1: There is significant relation between Attrition and YearsWithCurrManager
#
#
# 	Here, the P value of -0.156 is < 0.05 so we are rejecting H0
# 	Hence there is significant correlation between Attrition and YearsWithCurrManager
# 	As R = -0.156, there is low negative correlation between Attrition and YearsWithCurrManager
#
# ----------

# %% [markdown]
# # Plots to visualise the data

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Jointplot for Age amongst Attrited and Non-Attrited Employees

# %%
sns.set(style="darkgrid", color_codes=True)
sns.jointplot(df_y['Age'].sample(700), df_n['Age'].sample(700),
             data = df, kind = "reg", color = "b").annotate(pearsonr)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\axisgrid.py:1840: UserWarning: JointGrid annotation is deprecated and will be removed in a future release.
#   warnings.warn(UserWarning(msg))

# %% [raw]
# This plot also shows a regression line along with the pearson coefficient annotated

# %% [markdown]
# # Heat Map to visualise correlation

# %%
plt.figure(figsize=(24,24))
sns.heatmap(df.corr(),cmap='rainbow',annot=True)
plt.show()

# %% [raw]
# Looking at the heatmap we can conclude that attrition shares significant correlation with total working years, years at the company and years with current manager.

# %% [markdown]
# # Countplots for Job Role, Department, Education Field and Business travel of the employees

# %% [markdown]
# # Job role Count

# %%
sns.countplot(y="JobRole", hue="Attrition", data=df_chi)
plt.show()

# %% [markdown]
# # Department Count

# %%
sns.countplot(y="Department", hue="Attrition", data=df_chi)
plt.show()

# %% [markdown]
# # Education Field Count

# %%
sns.countplot(y="EducationField", hue="Attrition", data=df_chi)
plt.show()

# %% [markdown]
# # Business Travel Count

# %%
sns.countplot(y="BusinessTravel", hue="Attrition", data=df_chi)
plt.show()

# %% [markdown]
# # Summary

# %% [markdown]
# Attrition is high in Research and Development (R&D) and Sales departments, HR can focus on those departments and their employee satisfaction as to know the cause of high attrition.
#
# Research Scientist, Sales Executives and Laboratory Technicians are the top 3 job roles with high attrition.
#
# People who travel rarely tend to have a higher rate of attrition.
#
# Some of the fatcors that show significant difference among the employees regarding attrition:
#
# Number of companies worked at
# Total number of working years
# Percentage in salary hike
# Trainings taken last year
# Number of years since the last promotion
# Number of years with the current manager
# Attrition is also found to be dependent on the following:
#
# Marital Status
# Job Role
# Department
# Business Travel
# There is no dependency between Attrition and Gender.
